# %% [markdown]
# <div style="display: flex; align-items: center; background-color: #D3FFCE; padding: 40px;">
#     <div style="margin-left: 40px;">
#         <h2>MP03 Programació</h1>
#         <h4>Exercicis Llistes 2D</h3>
#         <p>Desenvolupeu els exercicis a les caselles buides sota cada exercici.</p>
#     </div>
#     <div-text-align: right;">
#         <img src="https://mataro.escolapia.cat/wp-content/uploads/2020/02/logo-caixa-EP-Mataro-300x183.png" alt="Logo" style="max-width: 70%; height: auto;">
#     </div>
# </div>

# %% [markdown]
# __Exercici 1:__
#
# Donada una taula de dues dimensions de 4 x 5, omplir la taula amb números i posteriorment calcular la suma dels seus elements.

# %% [markdown]
# __Exercici 2:__
#
# Donada una taula de dues dimensions de 4 x 5, omplir la taula amb números i posteriorment calcular la suma de cada fila i la suma de cada columna mostrant els 9 resultats per pantalla.

# %% [markdown]
# __Exercici 3:__
#
# Donada una taula de dues dimensions de 4 x 5, omplir la taula amb números i posteriorment buscar quin es el valor més gran i el més petit de cada fila, mostrant els 9 valors per pantalla.

# %% [markdown]
# __Exercici 4:__
#
# Fer un algorisme per transposar una matriu de 4x5. Transposar una matriu vol dir que les files passin a ser les columnes i les columnes les files.
#
# Ex.
#
#
# ```python
#         1 2 3
#         4 5 6
#
#         ->
#
#         1 4
#         2 5
#         3 6
# ```

# %% [markdown]
# __Exercici 5:__
#
# Fes un algorisme que sumi dues taules 4x5 i mostri el resultat per pantalla. Cal sumar els valors de la primera taula amb els de la segona i guardar-los en una nova taula.

# %% [markdown]
# __Exercici 6:__
#
# Defineix una taula de 4x5 d'enters. Després, l’usuari anirà indicant fila i columna i el que s’haurà de fer es eliminar el contingut de la casella indicada però arrossegant cap a l’esquerra totes les caselles següents. Finalitzarem quan l’usuari indiqui la coordenada 0,0 i mostrarem el contingut de la matriu al finalitzar l’algorisme.

# %% [markdown]
# __Exercici 7__
#
# És necessari crear un programa per tal d’introduir les notes d’un màxim de 10 alumnes que cursen 5 assignatures.
#
# Per tant, primer s’haurà de demanar el codiAlumne (matrícula) dels alumnes que volem avaluar, tenint en compte que com a màxim hi haurà 10 alumnes i que quan l’usuari vulgui dir que no hi ha més alumnes introduirà el codiAlumne igual a 0. S’ha de validar que el codiAlumne sempre ha de ser positiu perquè si l’usuari introdueix un codiAlumne negatiu s’haurà d’ignorar.
#
# D’altra banda, s’hauran d’introduir els 5 valors de nomAssignatura.
#
# Al final, l’usuari haurà d’introduir les notes per tots els alumnes informats per les 5 assignatures. El client ens ha demanat que vol introduir les notes per assignatura, és a dir, primer totes les notes de la primera assignatura, després de la segona... fins a cinquena.
#
# Evidentment, quan es demani la nota s’haurà de mostrar per pantalla de quin alumne i quina assignatura s’està demanant la nota. Existeix la possibilitat que un alumne no cursi una assignatura, en aquest cas el client posarà com a nota un -1, de tal manera que aquesta nota no haurà d’afectar els càlculs que posteriorment es demanen. Al final amb totes les notes introduïdes caldrà mostrar la següent informació.
#
# 1. Per cada assignatura la mitjana de notes, la més gran i la més petita.
# 2. Per cada alumne quants suspesos i quants aprovats té, a més de la mitjana de notes.
# 3. Dir quina és l'assignatura que té una nota mitjana més baixa.
