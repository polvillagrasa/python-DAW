# %% [markdown]
# <div style="display: flex; align-items: center; background-color: #D3FFCE; padding: 40px;">
#     <div style="margin-left: 40px;">
#         <h2>MP03 Programació</h1>
#         <h4>2. Exercicis Condicionals</h3>
#         <p>Desenvolupeu els exercicis a les caselles buides sota cada exercici.</p>
#     </div>
#     <div-text-align: right;">
#         <img src="https://mataro.escolapia.cat/wp-content/uploads/2020/02/logo-caixa-EP-Mataro-300x183.png" alt="Logo" style="max-width: 70%; height: auto;">
#     </div>
# </div>

# %% [markdown]
# __Exercici 1:__
#
# Introduir un número i visualitzar si és positiu, negatiu o neutre.

# %% [markdown]
# __Exercici 2:__
#
# Introduir dos números per teclat i indicar quin és més gran dels dos.

# %% [markdown]
# __Exercici 3:__
#
# Llegir un número pel teclat, si aquest és més gran de 20 mostrar com a resultat el número elevat a dos en cas contrari mostrar com a resultat el número elevat a 3.

# %% [markdown]
# __Exercici 4:__
#
# Introduir 4 números i dir si la suma dels dos primers és més gran, igual o més petit que la suma dels 2 següents.

# %% [markdown]
# __Exercici 5:__
#
# Elaborar un programa que determini en una variable “v_min” el més petit dels valors de 3 variables A,B,C

# %% [markdown]
# __Exercici 6:__
#
# Introduir 3 números i a continuació que els escrigui ordenats de major a menor.

# %% [markdown]
# __Exercici 7:__
#
# Introduir quatre caràcters per formar una contrasenya. La contrasenya només pot estar formada per números i lletres. Si s’introdueix algun altre caràcter, donarà error i el programa finalitzarà. Si tot ha estat introduit correctament mostrarem “contrasenya vàlida”.

# %% [markdown]
# __Exercici 8:__
#
# Fer un algorisme que serveixi tant per calcular l’àrea d’un rectangle com el perímetre d’un rectangle. Se li demanarà a l’usuari el valor dels dos costats i quina operació vol realitzar(A- àrea i P-perímetre) mostrant el resultat segons l’opció indicada per l’usuari.

# %% [markdown]
# __Exercici 9:__
#
# Demanar una nota numèrica a l'usuari i mostrar un text o un altre segons el rang de valors dins del qual es troba la nota:
# * Si és major o igual que 9 i menor o igual que 10, la nota és d’“Excel·lent”.
# * Si és major i igual que 6,5 però estrictament menor que 9, la nota és “Notable”.
# * Si és major i igual que 5 però estrictament menor que 6,5, la nota és “Suficient”.
# * Si no és cap dels casos anteriors, la nota és de “Suspès”.

# %% [markdown]
# __Exercici 10:__
#
# L’ordinador pensa un número entre 1 i 10, l’usuari l’intenta encertar, si és així mostrar un missatge d’enhorabona en cas contrari indicar que ha fallat.

# %% [markdown]
# __Exercici 11:__
#
# El mateix que el 24 però tenim 3 oportunitats i en cada número introduït ens indicarà si és més gran o més petit del número que ha indicat l’usuari.

# %% [markdown]
# __Exercici 12:__
#
# Donats dos enters c1 i c2 que representen números de cartes, imprimeix per pantalla -1, 0, 1 o 2 segons les següents regles:
# * Si alguna de les cartes no està entre 1 i 10, imprimeix -1
# * Si les cartes són iguals, imprimeix 0
# * Si les dues cartes són consecutives, en qualsevol ordre, imprimeix 1
# * Si no són consecutives, imprimeix 2
# Les regles s’han d’aplicar en l’ordre donat, és a dir, si les cartes són iguals però     no estan entre 1 i 10, el programa imprimirà -1 i no 0.

# %% [markdown]
# __Exercici 13:__
#
# Determinar la quantitat de diners que rebrà un treballador per concepte de les hores extres treballades en una empresa, sabent que quan les hores de treball excedeixen  de 40, la resta es consideren hores extres i que aquestes es paguen al doble d'una  hora normal quan no excedeixin de 8; si les hores extres excedeixen de 8 es paguen les primeres 8 al doble del que paguen les hores normals i la resta al triple.

# %% [markdown]
# __Exercici 14:__
#
# Calcular l'import que un treballador rep en el repartiment anual de beneficis si aquest se li assigna com un percentatge del seu salari mensual que depèn de la seva  antiguitat en l'empresa d'acord amb la taula:
#
# | Temps                                    | Percentatge        |
# |-----------------------------------------|--------------------|
# | Menys d’ 1 any.                         | 5% del salari      |
# | 1 anys o més i menys de 2 anys.         | 7% del salari      |
# | 2 anys o més i menys de 5 anys.         | 10% del salari     |
# | 5 anys o més i menys de 10 anys.        | 15% del salari     |
# | 10 anys o més.                          | 20% del salari     |
